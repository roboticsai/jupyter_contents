# %%
# Machine Learning:
# Examples/ applications ---->

# Banking --- fraud detection, customer service chatbot,  Credit score calculation ( PD, EAD, LGD)
# Insurance - Underwriting , Claim prob
# Retail/ CPG/ ----> planogram generation + Media + Forecasting
# ecommerce -- recommedatio engine , search engine
# Supply chain - Route optimization + Spend / Revenue management 
# Manufacturing - Defect detection, IoT ---faults identification, Self driving car
# HR - Attrition prediction , Culture fit prediction, CV shortlisting + (BGV analysis)
# Healthcare = medical imaging, disease diagnosis
# Telecommunication -- Churn prediction, Billing plan 

Horizontals -
   a) Customer Analytics --- acquired,Lifetime value, retained, churn,loyalty + Customer segmentatio
   b) Marketing analytics - Segment to target, Positing , CHannel to drive marketing , market share, market growth, competitive intelligence
       Paid install, SEO, SEM, Facebook, Google, Insta,Youtube , Times..., Hotsta
   c) Supply Chain
   d) Product Analytics/ Experience analytics ---> (Clickstream data) + Search engine optimization + Recommendation engine

# %%
How humans learn ? Experience



Whether Utsab is going to be a loan defaulter in next 1 yr?

I/Ps to machine learning model ------> historical data 
Y = f(X1,X2,X3,X4...)
Y = whether someone has defaulted(1/0)
X1 = Age , Salary....
Y ---> Target/ Dependent Variable (DV)
Xs ----> Predictors/ Independent variables(IDV)




O/P from the Machine---->
Y = 0.5X1^2 + 10^2.X2 + 20X3 +....


Prediction aboyt Utsab
Y = 0.5X1^2 + 10^2.X2 + 20X3 +....
and u need
X1,X2,X3 values for Utsab ( Utsab's age, sal, gender...)


Logic to derive this function:
    U as an user will specify the contour of the function---
    Y = f(X1,X2,X3,X4...) --- LINEAR RELATIONSHIP 
    Y = m1x1 + m2x2 + m3x3 + m4x4
    machine will find out what values of m1,m2,m3,m4 will cause the lowest possible error
    
    Y = f(X1,X2,X3,X4...) ---Non LINEAR RELATIONSHIP (each of these will mean different algorithms)


    Utsab, we saying we will give what function form / algorithm to use as an input? How will we
    know what algo to use for a given datset or what function form to use...I dont know is it linear/non linear relationship etc
     
TRIAL & ERROR METHOD ( Agorithm / model selection):
                           We will use all the algorithms that we think possible...or we want
                           whatever algorithm gives us the best accuracy --- we will assume
                           that function form is teh right form for the data
                           

                           
<> PLEASE NOTE:
        Logic to come up with right values of m1,m2,c etc ( model parameters) is basically based on 
        what values of m1,m2,c gives me the lowest error 
        
                           
        If u predict prob Utsab defaulting on a lon = 70%
                           or
        u say next month the sales = 100 Rs
                           
        Stakeholders --- how confident r u about ur outcome? If you quote the error/ accuracy that u
        got during learning the equation that would be incorrect....because u have learnt in such
        a way that it reduces the overall error.So it is biased estimate...
                           
                           
        In order to address that problem --- we divide our historical data in two parts -- i) TRAIN DATA
        ii) TEST DATA
        Train data --- used for learning the equation
        Tets data ----- used as a proxy for production data to report accuracy / error

# %%
Problem statement:
    Prediction problem statement (SUPERVISED PROBLEM STATEMENT)
    Is Utsab going to default
    Is Radhika going to buy
    Is this transaction fraudelent?
    Is this employee going to attrite?
    
Data Requirement:
    I need historical data where X and Y values are present (labelled data)
    
Data preprocessing:
    a) Missing values tretament
    b) Outlier treatment
    c) Categorical variables --- dummy variables
    d) Choosing best features and removing unwanted features (IDVs)
    
Data Splitting into Train and Test:
    a) Historical data needs to randomly splitted into train and test...recommended split is
       75% train data - 25% test data
    

Identify the type of problem (Regression / Classification / Time series forecasting):
    a) Regression is when Y is a continuous variable: Example - u want to predict salary, predict houseprice
        predict alcohol content in a liquid...
    b) Classification is when Y is a categorical variable:
           --- Binary --- Utsab will buy or not? Abhishek will default or not? Frud or not, obese or not
           --- Multiclass --- Utsab will buy mobile or lifestyle or books?
    c) Time series forecasting --- Autocorrelation exists ...rows are not independent
    
User should provide following input:
    a) User has to tell machine what is Y and what are X variables in the data 
    that helps machine to understand it needs to learn only relationship between Y and X and not anything else
    Y = f(X1,X2,X3) --- exactly that is the reason why it is called supervised 
    
    b) Also provides what algorithm / relationship to explore
    
Machine starts learning:
    It learns the true hidden relationship between Y and X by minimizing the error on training data
    
Machine starts prediction:
    using the relationship learnt machine will now do prediction on test data . And we will calclate
    some measure of accuracy / error 
    
Iterative process of model selection:
    If u r not happy with accuracy , u can evaluate other algorithms possible and see if any of them
    guves better result
    Once u r happy with the model...u need to finalize that
    
Deployment / production:
    We will store the model in harddisk (Y = 0.5X1+0.2X2 ...etc will be stored in my Harddisk)
    We have a REST API which loads the model and listens to a port
    now say a web applications sends a json message with X values...
    API parses the X values and passes to the model
    model is going to do the prediction
    and then API will send a JSON message back to web application and someone willl get to see the outcome

# %%
Data Preprocessing details:
    Objective of data preprocssing is to convert the raw daa into a a clean dtaaset
    a) Data cleaning  b) Data Transformation   c) Data reduction
    Missing value, outlier, categorical - dummy, Scaling of variable
    
Data Wrangling:
    Objective - the preprocessing required to get insights from the cleaned data
    Groupby, filtering the data, pivot , correlation
    does age influence income?
    does different salary bracket has different chance of default

# %%
Problem Statement (UNSUPERVISED PROBLEM):
    Profile = Characteristics
    Profile of customers who are buying from us? Profile of customers who are not buying from us?
    Profile of employees who are staying with us and leaving us?
    Profile of all the defected products?
    Profile of all the purchase baskets?
    Recommending products / videos to similar users
    
Data Requirement:
    No label available. No Y variable available...
   
Logic:
    ML algorithm will check for similarity between observations and will group similar observations
    together (CLUSTERS)
    Within cluster it is expected that the avg behavior of all the data points are more or less
    same...the datapoints within cluster are homogenius and between clusters are heterogeneious
    
    MACHINE LEARNING ALGORITHM IN THIS CASE IS VERY VERY PRIMITIVE AND WILL NOT BE ABLE TO TELL
    HOW MANY GROUPS/ CLUSTERS ARE THERE IN THE DATA 
    NO. of clusters = USER INPUT
    
    
    We will be get some idea/guidance based on what no of clusters gives us best homogeneity with the cluster
    and heterogenity between the cluster
    
    NO RIGHT / WRONG ANSWER HERE

Answers:
    We will assign every observation (rows, customers/employees/products) as part of a group
    (ML algo will check for similarity and will group them)
    
    
    What is the characteristics of each of these group ( manual insights method)
    
IN case of unsupervised algorithm there is no accuracy /error ...because i do not have any thing to compare

    
Business goal --
    Trump win 
    Modi win
    Targetting of advertisements
# Out:
#   File "<ipython-input-1-e5cafbb2129c>", line 1
#     Problem Statement (UNSUPERVISED PROBLEM):
#                     ^
# SyntaxError: invalid syntax

# %%
Batchprocessing
Realtime processing
Near relatime processing (sync & async)
